# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleli142/dighum101/blob/master/MichelleLi_DH100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PISA Scores Analysis-Dighum100**

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
#Loading in the datasets into dataframes
country = pd.read_csv('/EdStatsCountry.csv')
indicators = pd.read_csv('/EdStatsSeries.csv')
scores = pd.read_csv('/')

# %%
#Exploratory data analysis
counts = country.groupby(['Income Group']).count()
counts['Country Code'].plot(kind = 'bar', title = 'Counts of Countries by Income Group', rot = 45)

# %%
#More EDA
country
# Out:
#     Country Code    Short Name  ... Latest water withdrawal data Unnamed: 31
# 0            ABW         Aruba  ...                          NaN         NaN
# 1            AFG   Afghanistan  ...                         2000         NaN
# 2            AGO        Angola  ...                         2005         NaN
# 3            ALB       Albania  ...                         2006         NaN
# 4            AND       Andorra  ...                          NaN         NaN
# ..           ...           ...  ...                          ...         ...
# 236          XKX        Kosovo  ...                          NaN         NaN
# 237          YEM         Yemen  ...                         2005         NaN
# 238          ZAF  South Africa  ...                         2000         NaN
# 239          ZMB        Zambia  ...                         2002         NaN
# 240          ZWE      Zimbabwe  ...                         2002         NaN
#
# [241 rows x 32 columns]

# %%
#From here on, I am going to make a heatmap and then explore correlation some more.
